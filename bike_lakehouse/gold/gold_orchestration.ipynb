# %% [markdown]
# # Silver Orchestration
# This notebook programmatically runs all Gold notebooks in sequence. It becomes the single entry point for the gold layer in Databricks Jobs

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
